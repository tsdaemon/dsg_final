# %%
import pandas as pd
import itertools
from sklearn.linear_model import Ridge
from dateutil.relativedelta import relativedelta
from sklearn.metrics import mean_absolute_error
import numpy as np
# %matplotlib inline
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
data = pd.read_csv('/dsg/demand_anonymized_20170802.csv', delimiter=';', parse_dates=["Month"])
eval = pd.read_csv('/dsg/eval.csv')

# %%
# create aggregated by month series
series = data.groupby(["SalOrg", "Material", "Month"])["OrderQty"].sum().reset_index()
series = series.sort_values(by=["SalOrg", "Material", "Month"])
series.head()
# Out:
#   SalOrg Material      Month  OrderQty
# 0   97LK   00IYcj 2012-05-01         2
# 1   97LK   00IYcj 2012-06-01        13
# 2   97LK   00IYcj 2012-07-01         1
# 3   97LK   00IYcj 2012-09-01        30
# 4   97LK   00IYcj 2012-11-01         1

# %%
# fill empty
eval_comb = eval[['Material', 'SalOrg']]
eval_comb = list(set([tuple(x) for x in eval_comb.values]))

comb = list(itertools.product(*[eval_comb, list(series['Month'].unique())]))
comb = [(t[0], t[1], m) for t, m in comb]

series2 = pd.DataFrame(comb, columns=['Material', 'SalOrg', 'Month'])
series2 = series2.sort_values(by=['Material', 'SalOrg', 'Month' ])
series2 = series2.merge(series, on=['Month', 'Material', 'SalOrg'], how='left')
series2 = series2.fillna(0)

# %%
series2['OrderQtyLog'] = np.log1p(series2['OrderQty'])

# %%
# create lagged features
def lag_feature(df, colname, lag, adv):
    cols_lagged = []
    for i in range(lag, 0, -1):
        col_lagged = '{}(t-{})'.format(colname, i)
        df[col_lagged] = df.groupby(by=['SalOrg', 'Material'])[colname].shift(i)
        cols_lagged.append(col_lagged)
    cols_adv = []
    for i in range(1, adv):
        col_adv = '{}(t+{})'.format(colname, i)
        df[col_adv] = df.groupby(by=['SalOrg', 'Material'])[colname].shift(-i)
        cols_adv.append(col_adv) 
        
    return df, cols_lagged, cols_adv

series, lagged, adv = lag_feature(series2, 'OrderQtyLog', 12, 3)
series.head()
# Out:
#   Material SalOrg      Month  OrderQty  OrderQtyLog  OrderQtyLog(t-12)  \
# 0   00GB1f   yqSu 2012-01-01       0.0     0.000000                NaN
# 1   00GB1f   yqSu 2012-02-01       0.0     0.000000                NaN
# 2   00GB1f   yqSu 2012-03-01       1.0     0.693147                NaN
# 3   00GB1f   yqSu 2012-04-01       3.0     1.386294                NaN
# 4   00GB1f   yqSu 2012-05-01       2.0     1.098612                NaN
#
#    OrderQtyLog(t-11)  OrderQtyLog(t-10)  OrderQtyLog(t-9)  OrderQtyLog(t-8)  \
# 0                NaN                NaN               NaN               NaN
# 1                NaN                NaN               NaN               NaN
# 2                NaN                NaN               NaN               NaN
# 3                NaN                NaN               NaN               NaN
# 4                NaN                NaN               NaN               NaN
#
#    OrderQtyLog(t-7)  OrderQtyLog(t-6)  OrderQtyLog(t-5)  OrderQtyLog(t-4)  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               0.0
#
#    OrderQtyLog(t-3)  OrderQtyLog(t-2)  OrderQtyLog(t-1)  OrderQtyLog(t+1)  \
# 0               NaN               NaN               NaN          0.000000
# 1               NaN               NaN          0.000000          0.693147
# 2               NaN          0.000000          0.000000          1.386294
# 3               0.0          0.000000          0.693147          1.098612
# 4               0.0          0.693147          1.386294          0.693147
#
#    OrderQtyLog(t+2)
# 0          0.693147
# 1          1.386294
# 2          1.098612
# 3          0.693147
# 4          1.386294

# %%
# validation folds
def create_validation(data, date, m):
    return data[(data["Month"] > pd.to_datetime(date) - relativedelta(months=m))&
                (data["Month"] < pd.to_datetime(date))].index, data[(data["Month"] >= pd.to_datetime(date)) & 
                (data["Month"] < pd.to_datetime(date) + relativedelta(months=3))].index

validation_months = ['2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01']

folds = []
for month in validation_months:
    folds.append(create_validation(series, month, 6))

# %%
all = len(series.groupby(by=['SalOrg', 'Material']))

# %%
errors = {}
all_errors = []

for fold in folds:   
    fold_errors = []
    
    processed = 1
    prev_mean_error = 1000
    for index, group in series.groupby(by=['SalOrg', 'Material']):
        #model_name = index[0] + '_' + index[1]
        if index not in errors:
            errors[index] = []
        
        train_s = group.loc[group.index.intersection(fold[0])]
        test_s = group.loc[group.index.intersection(fold[1])]
        
        assert (train_s['SalOrg'] == index[0]).all()
        assert (train_s['Material'] == index[1]).all()
        
        assert (test_s['SalOrg'] == index[0]).all()
        assert (test_s['Material'] == index[1]).all()
        
        train_y = train_s[['OrderQtyLog'] + adv]
        train_x = train_s[lagged]

        test_y = test_s[['OrderQtyLog'] + adv]
        test_x = test_s[lagged]

        model = Ridge(alpha=5)
        model.fit(train_x, train_y)

        test_y_predicted = model.predict(test_x)
        test_y_predicted[test_y_predicted < 0] = 0
        
        try:
            error = mean_absolute_error(np.expm1(test_y), np.expm1(test_y_predicted))
        except:
            print(test_y)
            print(test_y_predicted)
        
        errors[index].append(error)
        all_errors.append(error)
        fold_errors.append(error)
        
        processed += 1
        if(processed % 1000 == 0):
            print('Trained {}/{} models, mean fold error: {}'.format(processed, all, np.mean(fold_errors)))
        
    print('Mean fold error: {}'.format(np.mean(fold_errors)))
    
np.mean(all_errors)
# Out:
# Trained 1000/38676 models, mean fold error: 12.02466462819433
# Trained 2000/38676 models, mean fold error: 13.079447247778694
# Trained 3000/38676 models, mean fold error: 10.909124072681525
# Trained 4000/38676 models, mean fold error: 12.083152183257338
# Trained 5000/38676 models, mean fold error: 12.081004247002847
# Trained 6000/38676 models, mean fold error: 12.365692047743586
# Trained 7000/38676 models, mean fold error: 11.516320367860095
# Trained 8000/38676 models, mean fold error: 12.670369452124513
# Trained 9000/38676 models, mean fold error: 12.308668348423506
# Trained 10000/38676 models, mean fold error: 12.063126797799256
# Trained 11000/38676 models, mean fold error: 12.922863119583964
# Trained 12000/38676 models, mean fold error: 12.417167639032902
# Trained 13000/38676 models, mean fold error: 11.835978349215397
# Trained 14000/38676 models, mean fold error: 11.59470430953959
# Trained 15000/38676 models, mean fold error: 11.5787469674509
# Trained 16000/38676 models, mean fold error: 11.29581255424382
# Trained 17000/38676 models, mean fold error: 11.122986119191792
# Trained 18000/38676 models, mean fold error: 10.986225668612818
# Trained 19000/38676 models, mean fold error: 10.912701667132886
# Trained 20000/38676 models, mean fold error: 10.98640810002251
# Trained 21000/38676 models, mean fold error: 10.804048027605011
# Trained 22000/38676 models, mean fold error: 10.81215772338151
# Trained 23000/38676 models, mean fold error: 10.811927640323933
# Trained 24000/38676 models, mean fold error: 10.782551896522858
# Trained 25000/38676 models, mean fold error: 10.707454151442718
# Trained 26000/38676 models, mean fold error: 10.618444013241703
# Trained 27000/38676 models, mean fold error: 10.915597273219463
# Trained 28000/38676 models, mean fold error: 11.284347694819182
# Trained 29000/38676 models, mean fold error: 11.965705833071096
# Trained 30000/38676 models, mean fold error: 12.778269897656658
# Trained 31000/38676 models, mean fold error: 13.262760342530521
# Trained 32000/38676 models, mean fold error: 13.236602536572452
# Trained 33000/38676 models, mean fold error: 13.410827469416578
# Trained 34000/38676 models, mean fold error: 13.43825802716177
# Trained 35000/38676 models, mean fold error: 13.451071581332618
# Trained 36000/38676 models, mean fold error: 13.488162741264025
# Trained 37000/38676 models, mean fold error: 13.745607812478976
# Trained 38000/38676 models, mean fold error: 13.736657018936647
# Mean fold error: 13.825173881781712
# Trained 1000/38676 models, mean fold error: 13.931807921254215
# Trained 2000/38676 models, mean fold error: 15.240084084068194
# Trained 3000/38676 models, mean fold error: 12.798555725773637
# Trained 4000/38676 models, mean fold error: 13.658424991366328
# Trained 5000/38676 models, mean fold error: 13.527585459274801
# Trained 6000/38676 models, mean fold error: 13.855044871668278
# Trained 7000/38676 models, mean fold error: 12.97153494806405
# Trained 8000/38676 models, mean fold error: 14.081871106665469
# Trained 9000/38676 models, mean fold error: 13.750264748824389
# Trained 10000/38676 models, mean fold error: 13.501197065237905
# Trained 11000/38676 models, mean fold error: 13.227075268504127
# Trained 12000/38676 models, mean fold error: 12.6922054099842
# Trained 13000/38676 models, mean fold error: 12.10347454538583
# Trained 14000/38676 models, mean fold error: 11.809086283448636
# Trained 15000/38676 models, mean fold error: 11.741443954827277
# Trained 16000/38676 models, mean fold error: 11.43639239521908
# Trained 17000/38676 models, mean fold error: 11.249294144366015
# Trained 18000/38676 models, mean fold error: 11.075200207091529
# Trained 19000/38676 models, mean fold error: 10.938598855109879
# Trained 20000/38676 models, mean fold error: 10.97365620741659
# Trained 21000/38676 models, mean fold error: 10.788496164722387
# Trained 22000/38676 models, mean fold error: 10.75218227117341
# Trained 23000/38676 models, mean fold error: 10.818044876303327
# Trained 24000/38676 models, mean fold error: 10.749652633756988
# Trained 25000/38676 models, mean fold error: 10.639221035799908
# Trained 26000/38676 models, mean fold error: 10.537726177434019
# Trained 27000/38676 models, mean fold error: 10.825291862139808
# Trained 28000/38676 models, mean fold error: 11.166127551660729
# Trained 29000/38676 models, mean fold error: 11.675061019515363
# Trained 30000/38676 models, mean fold error: 11.972474230969
# Trained 31000/38676 models, mean fold error: 12.083600832726853
# Trained 32000/38676 models, mean fold error: 12.117415321137518
# Trained 33000/38676 models, mean fold error: 12.360903649415913
# Trained 34000/38676 models, mean fold error: 23.696305922292055
# Trained 35000/38676 models, mean fold error: 23.405078099440104
# Trained 36000/38676 models, mean fold error: 23.15045364377733
# Trained 37000/38676 models, mean fold error: 23.039542311814657
# Trained 38000/38676 models, mean fold error: 22.767760129287137
# Mean fold error: 22.72344276044837
# Trained 1000/38676 models, mean fold error: 13.852183808078061
# Trained 2000/38676 models, mean fold error: 14.957191283900626
# Trained 3000/38676 models, mean fold error: 12.802360479258706
# Trained 4000/38676 models, mean fold error: 13.176591193477812
# Trained 5000/38676 models, mean fold error: 13.057120395581414
# Trained 6000/38676 models, mean fold error: 13.366144860561851
# Trained 7000/38676 models, mean fold error: 12.583866479103136
# Trained 8000/38676 models, mean fold error: 13.446453721840374
# Trained 9000/38676 models, mean fold error: 13.170922254651654
# Trained 10000/38676 models, mean fold error: 13.000101872853156
# Trained 11000/38676 models, mean fold error: 12.769847759337726
# Trained 12000/38676 models, mean fold error: 12.218942641839158
# Trained 13000/38676 models, mean fold error: 11.640955195608976
# Trained 14000/38676 models, mean fold error: 11.319173832555292
# Trained 15000/38676 models, mean fold error: 11.211077070638911
# Trained 16000/38676 models, mean fold error: 10.895622367185434
# Trained 17000/38676 models, mean fold error: 10.700835538150793
# Trained 18000/38676 models, mean fold error: 10.51599770983772
# Trained 19000/38676 models, mean fold error: 10.352833294412774
# Trained 20000/38676 models, mean fold error: 10.312851715309936
# Trained 21000/38676 models, mean fold error: 10.09839167178819
# Trained 22000/38676 models, mean fold error: 10.02055629104435
# Trained 23000/38676 models, mean fold error: 10.048066645540873
# Trained 24000/38676 models, mean fold error: 9.931214355920405
# Trained 25000/38676 models, mean fold error: 9.797324587125917
# Trained 26000/38676 models, mean fold error: 9.69327596613647
# Trained 27000/38676 models, mean fold error: 9.912380079454323
# Trained 28000/38676 models, mean fold error: 10.195938189176271
# Trained 29000/38676 models, mean fold error: 11.099812685326892
# Trained 30000/38676 models, mean fold error: 11.278030048668775
# Trained 31000/38676 models, mean fold error: 11.339029418078038
# Trained 32000/38676 models, mean fold error: 11.354092928294634
# Trained 33000/38676 models, mean fold error: 11.614191512238836
# Trained 34000/38676 models, mean fold error: 11.811634742158503
# Trained 35000/38676 models, mean fold error: 11.839004270529092
# Trained 36000/38676 models, mean fold error: 11.860741947465023
# Trained 37000/38676 models, mean fold error: 12.035955961262495
# Trained 38000/38676 models, mean fold error: 12.01033998998921
# Mean fold error: 12.095123063984957
# Trained 1000/38676 models, mean fold error: 13.176386190783361
# Trained 2000/38676 models, mean fold error: 14.41971827807789
# Trained 3000/38676 models, mean fold error: 12.794543495013476
# Trained 4000/38676 models, mean fold error: 13.23544935524297
# Trained 5000/38676 models, mean fold error: 13.111781607826464
# Trained 6000/38676 models, mean fold error: 13.332261612554804
# Trained 7000/38676 models, mean fold error: 12.604699157655745
# Trained 8000/38676 models, mean fold error: 13.462610797830758
# Trained 9000/38676 models, mean fold error: 13.197136861310712
# Trained 10000/38676 models, mean fold error: 13.045351259008209
# Trained 11000/38676 models, mean fold error: 12.862310869536307
# Trained 12000/38676 models, mean fold error: 12.27497950728345
# Trained 13000/38676 models, mean fold error: 11.68649852159484
# Trained 14000/38676 models, mean fold error: 11.292613902530773
# Trained 15000/38676 models, mean fold error: 11.159434616425946
# Trained 16000/38676 models, mean fold error: 10.835829401835293
# Trained 17000/38676 models, mean fold error: 10.619214177292559
# Trained 18000/38676 models, mean fold error: 10.424169987088073
# Trained 19000/38676 models, mean fold error: 10.225177952704035
# Trained 20000/38676 models, mean fold error: 10.103657628237961
# Trained 21000/38676 models, mean fold error: 9.87290474318161
# Trained 22000/38676 models, mean fold error: 9.730507736162465
# Trained 23000/38676 models, mean fold error: 9.759956648649121
# Trained 24000/38676 models, mean fold error: 9.604844881443018
# Trained 25000/38676 models, mean fold error: 9.45421371340695
# Trained 26000/38676 models, mean fold error: 9.342517511427593
# Trained 27000/38676 models, mean fold error: 9.540137228722935
# Trained 28000/38676 models, mean fold error: 9.859487352582075
# Trained 29000/38676 models, mean fold error: 10.413456762910888
# Trained 30000/38676 models, mean fold error: 10.588822180724819
# Trained 31000/38676 models, mean fold error: 10.698255229122932
# Trained 32000/38676 models, mean fold error: 10.718131616603221
# Trained 33000/38676 models, mean fold error: 10.977855038881177
# Trained 34000/38676 models, mean fold error: 11.184628937798253
# Trained 35000/38676 models, mean fold error: 11.202924182117235
# Trained 36000/38676 models, mean fold error: 11.225915092957202
# Trained 37000/38676 models, mean fold error: 11.318998429688525
# Trained 38000/38676 models, mean fold error: 11.313590717139906
# Mean fold error: 11.397065088493425
# 15.010201198677116
